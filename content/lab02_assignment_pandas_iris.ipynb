# %% [markdown]
# # Lab 02: Analyzing a Dataset with Pandas (Iris)
# **Course:** CSE473 Computational Intelligence — Mechatronics Engineering and Automation Program
# **Due:** See course portal
# **Points:** 100

# %% [markdown]
# ## Objective
# Use the pandas library to load the **Iris dataset** (measurements of 150 iris flowers from three species: *setosa*, *versicolor*, *virginica*; each described by four features: sepal length, sepal width, petal length, petal width), explore its structure, clean the data, and perform basic analysis to gain insights.

# %% [markdown]
# ## Task 1: Load the Dataset (15 pts)
# Load the Iris dataset into a pandas DataFrame named `df`. The cell below tries `seaborn.load_dataset('iris')` first and falls back to an embedded CSV copy if the notebook runs offline (e.g. in JupyterLite without internet).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# The Iris dataset: 150 flowers, 3 species, 4 numeric features.
# Primary source: seaborn (works online in JupyterLite).
# Fallback: the embedded CSV below (works fully offline).
IRIS_CSV = """sepal_length,sepal_width,petal_length,petal_width,species
5.1,3.5,1.4,0.2,setosa
4.9,3.0,1.4,0.2,setosa
4.7,3.2,1.3,0.2,setosa
4.6,3.1,1.5,0.2,setosa
5.0,3.6,1.4,0.2,setosa
5.4,3.9,1.7,0.4,setosa
4.6,3.4,1.4,0.3,setosa
5.0,3.4,1.5,0.2,setosa
4.4,2.9,1.4,0.2,setosa
4.9,3.1,1.5,0.1,setosa
5.4,3.7,1.5,0.2,setosa
4.8,3.4,1.6,0.2,setosa
4.8,3.0,1.4,0.1,setosa
4.3,3.0,1.1,0.1,setosa
5.8,4.0,1.2,0.2,setosa
5.7,4.4,1.5,0.4,setosa
5.4,3.9,1.3,0.4,setosa
5.1,3.5,1.4,0.3,setosa
5.7,3.8,1.7,0.3,setosa
5.1,3.8,1.5,0.3,setosa
5.4,3.4,1.7,0.2,setosa
5.1,3.7,1.5,0.4,setosa
4.6,3.6,1.0,0.2,setosa
5.1,3.3,1.7,0.5,setosa
4.8,3.4,1.9,0.2,setosa
5.0,3.0,1.6,0.2,setosa
5.0,3.4,1.6,0.4,setosa
5.2,3.5,1.5,0.2,setosa
5.2,3.4,1.4,0.2,setosa
4.7,3.2,1.6,0.2,setosa
4.8,3.1,1.6,0.2,setosa
5.4,3.4,1.5,0.4,setosa
5.2,4.1,1.5,0.1,setosa
5.5,4.2,1.4,0.2,setosa
4.9,3.1,1.5,0.2,setosa
5.0,3.2,1.2,0.2,setosa
5.5,3.5,1.3,0.2,setosa
4.9,3.6,1.4,0.1,setosa
4.4,3.0,1.3,0.2,setosa
5.1,3.4,1.5,0.2,setosa
5.0,3.5,1.3,0.3,setosa
4.5,2.3,1.3,0.3,setosa
4.4,3.2,1.3,0.2,setosa
5.0,3.5,1.6,0.6,setosa
5.1,3.8,1.9,0.4,setosa
4.8,3.0,1.4,0.3,setosa
5.1,3.8,1.6,0.2,setosa
4.6,3.2,1.4,0.2,setosa
5.3,3.7,1.5,0.2,setosa
5.0,3.3,1.4,0.2,setosa
7.0,3.2,4.7,1.4,versicolor
6.4,3.2,4.5,1.5,versicolor
6.9,3.1,4.9,1.5,versicolor
5.5,2.3,4.0,1.3,versicolor
6.5,2.8,4.6,1.5,versicolor
5.7,2.8,4.5,1.3,versicolor
6.4,2.8,5.6,2.2,virginica
6.3,2.8,5.1,1.5,virginica
6.1,2.6,5.6,1.4,virginica
7.7,3.0,6.1,2.3,virginica
6.3,3.4,5.6,2.4,virginica
6.4,3.1,5.5,1.8,virginica
6.0,3.0,4.8,1.8,virginica
6.9,3.1,5.4,2.1,virginica
6.7,3.1,5.6,2.4,virginica
6.9,3.1,5.1,2.3,virginica
5.8,2.7,5.1,1.9,virginica
6.8,3.2,5.9,2.3,virginica
6.7,3.3,5.7,2.5,virginica
6.7,3.0,5.2,2.3,virginica
6.3,2.5,5.0,1.9,virginica
6.5,3.0,5.2,2.0,virginica
6.2,3.4,5.4,2.3,virginica
5.9,3.0,5.1,1.8,virginica
"""

try:
    import seaborn as sns
    df = sns.load_dataset("iris")
    df.columns = [c.replace(" ", "_") for c in df.columns]
except Exception:
    # Offline fallback: build the DataFrame from the embedded CSV
    from io import StringIO
    df = pd.read_csv(StringIO(IRIS_CSV))

print(f"Loaded {len(df)} rows, columns: {list(df.columns)}")

# %% [markdown]
# ## Task 2: Explore the Dataset (25 pts)
# Fill in the variables below:
# - `first_10_rows` — the first 10 rows of the DataFrame (`df.head(...)`),
# - `data_types` — the dtype of each column (`df.dtypes`),
# - `missing_values` — count of missing values per column (`df.isnull()...`),
# - `basic_statistics` — basic statistics for each numerical column (`df.describe()`).

# %%
# TODO: first 10 rows of the DataFrame
first_10_rows = None

# TODO: data type of each column
data_types = None

# TODO: count of missing values per column
missing_values = None

# TODO: basic statistics of the numerical columns
basic_statistics = None

print(first_10_rows)
print("Missing values per column:\n", missing_values)

# %% [markdown]
# ## Task 3: Data Cleaning (15 pts)
# Check for missing values and handle them: for numerical columns, fill missing entries with the column mean (keeps the dtype numeric). Store the result in `df_clean` and verify no missing values remain.

# %%
df_clean = df.copy()

# TODO: for each numerical column with missing values, fill them with the column mean
# Hint: df_clean.select_dtypes(include=[np.number]) loops over numerical columns

print("Missing values after cleaning:", df_clean.isnull().sum().sum())

# %% [markdown]
# ## Task 4: Data Analysis (45 pts)
# Compute and store:
# - `mean_per_column` and `median_per_column` — mean and median of each numerical column,
# - `correlation_matrix` — correlation between the numerical features (`df.corr()`),
# - `grouped_means` — group the data by species and compute the mean of each feature within each species,
# - a figure with a histogram for each numerical feature.

# %%
# TODO: mean of each numerical column
mean_per_column = None

# TODO: median of each numerical column
median_per_column = None

# TODO: correlation matrix of the numerical features
correlation_matrix = None

# TODO: group by species and compute the mean of each feature
grouped_means = None

print("Means:\n", mean_per_column)
print("\nMedians:\n", median_per_column)
print("\nCorrelation matrix:\n", correlation_matrix)
print("\nPer-species means:\n", grouped_means)

# %%
# TODO: plot a histogram for each numerical feature
numerical_columns = list(df_clean.select_dtypes(include=[np.number]).columns)
fig, axes = plt.subplots(1, len(numerical_columns), figsize=(4 * len(numerical_columns), 3))
for ax, col in zip(np.atleast_1d(axes), numerical_columns):
    pass  # TODO: draw df_clean[col].hist(...) on ax and label it
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Submission
# 1. Run all cells to verify correctness.
# 2. Download this notebook (File > Download > .ipynb).
# 3. Upload to the course portal.
